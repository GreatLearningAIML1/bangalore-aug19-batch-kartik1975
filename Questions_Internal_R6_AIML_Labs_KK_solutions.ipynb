# %% [markdown]
# <a href="https://colab.research.google.com/github/GreatLearningAIML1/bangalore-aug19-batch-kartik1975/blob/master/Questions_Internal_R6_AIML_Labs_KK_solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The Iris Dataset
# The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# The dataset contains a set of 150 records under five attributes - petal length, petal width, sepal length, sepal width and species.

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
irisdataset = load_iris()

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Import dataset
# - Import iris dataset
# - Import the dataset using sklearn library

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
irisdataset = load_iris()

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - you can get the features using .data method
# - you can get the features using .target method

# %%
X = irisdataset.data

# %%
y = irisdataset.target

# %%
X.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %% [markdown]
# ## Question 3

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ### Create train and test data
# - use train_test_split to get train and test set
# - set a random_state
# - test_size: 0.25

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=1)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (112, 4)
# (112,)
# (38, 4)
# (38,)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### One-hot encode the labels
# - convert class vectors (integers) to binary class matrix
# - convert labels
# - number of classes: 3
# - we are doing this to use categorical_crossentropy as loss

# %%
from keras.utils import to_categorical
y_test=to_categorical(y_test, num_classes=3)
y_train=to_categorical(y_train, num_classes=3)

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Initialize a sequential model
# - Define a sequential model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = tf.keras.Sequential()

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Add a layer
# - Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3
# - Apply Softmax on Dense Layer outputs

# %%
# Add an input layer  
model.add(Dense(4, activation='sigmoid', input_shape=(4,)))   

# Add an output layer  
model.add(Dense(3, activation='softmax'))

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Compile the model
# - Use SGD as Optimizer
# - Use categorical_crossentropy as loss function
# - Use accuracy as metrics

# %%
model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Summarize the model
# - Check model layers
# - Understand number of trainable parameters

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 15
# =================================================================
# Total params: 35
# Trainable params: 35
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Fit the model
# - Give train data as training features and labels
# - Epochs: 100
# - Give validation data as testing features and labels

# %%
history=model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=1)
# Out:
# Train on 112 samples
# Epoch 1/100
# 112/112 [==============================] - 0s 3ms/sample - loss: 1.1069 - accuracy: 0.4464
# Epoch 2/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 1.0391 - accuracy: 0.6786
# Epoch 3/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.9970 - accuracy: 0.6875
# Epoch 4/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.9576 - accuracy: 0.6964
# Epoch 5/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.9205 - accuracy: 0.6964
# Epoch 6/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.8841 - accuracy: 0.7054
# Epoch 7/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.8500 - accuracy: 0.6964
# Epoch 8/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.8160 - accuracy: 0.6964
# Epoch 9/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.7831 - accuracy: 0.6964
# Epoch 10/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.7538 - accuracy: 0.6964
# Epoch 11/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.7258 - accuracy: 0.7054
# Epoch 12/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.7012 - accuracy: 0.6964
# Epoch 13/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.6777 - accuracy: 0.7054
# Epoch 14/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.6575 - accuracy: 0.6964
# Epoch 15/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.6385 - accuracy: 0.6964
# Epoch 16/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.6213 - accuracy: 0.7054
# Epoch 17/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.6043 - accuracy: 0.7232
# Epoch 18/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.5916 - accuracy: 0.6964
# Epoch 19/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.5766 - accuracy: 0.7500
# Epoch 20/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.5652 - accuracy: 0.7143
# Epoch 21/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.5553 - accuracy: 0.7054
# Epoch 22/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.5442 - accuracy: 0.7232
# Epoch 23/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.5355 - accuracy: 0.7143
# Epoch 24/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.5253 - accuracy: 0.7857
# Epoch 25/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.5183 - accuracy: 0.7589
# Epoch 26/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.5098 - accuracy: 0.7679
# Epoch 27/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.5008 - accuracy: 0.7589
# Epoch 28/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.4918 - accuracy: 0.8750
# Epoch 29/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4884 - accuracy: 0.8036
# Epoch 30/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4805 - accuracy: 0.8036
# Epoch 31/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.4742 - accuracy: 0.8393
# Epoch 32/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4667 - accuracy: 0.8304
# Epoch 33/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4605 - accuracy: 0.8661
# Epoch 34/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4518 - accuracy: 0.8571
# Epoch 35/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4467 - accuracy: 0.8839
# Epoch 36/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4417 - accuracy: 0.8661
# Epoch 37/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4355 - accuracy: 0.8839
# Epoch 38/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.4285 - accuracy: 0.8929
# Epoch 39/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.4239 - accuracy: 0.9018
# Epoch 40/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.4150 - accuracy: 0.9018
# Epoch 41/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.4117 - accuracy: 0.9196
# Epoch 42/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.4051 - accuracy: 0.9196
# Epoch 43/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3981 - accuracy: 0.9643
# Epoch 44/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3949 - accuracy: 0.9196
# Epoch 45/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3870 - accuracy: 0.9286
# Epoch 46/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.3805 - accuracy: 0.9196
# Epoch 47/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3716 - accuracy: 0.9464
# Epoch 48/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3664 - accuracy: 0.9196
# Epoch 49/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.3655 - accuracy: 0.9375
# Epoch 50/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.3591 - accuracy: 0.9464
# Epoch 51/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.3476 - accuracy: 0.9286
# Epoch 52/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3479 - accuracy: 0.9375
# Epoch 53/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3430 - accuracy: 0.9554
# Epoch 54/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.3361 - accuracy: 0.9554
# Epoch 55/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3311 - accuracy: 0.9464
# Epoch 56/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.3278 - accuracy: 0.9554
# Epoch 57/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3193 - accuracy: 0.9375
# Epoch 58/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3174 - accuracy: 0.9464
# Epoch 59/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3111 - accuracy: 0.9554
# Epoch 60/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.3065 - accuracy: 0.9464
# Epoch 61/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.3002 - accuracy: 0.9464
# Epoch 62/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2961 - accuracy: 0.9464
# Epoch 63/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2905 - accuracy: 0.9643
# Epoch 64/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2848 - accuracy: 0.9554
# Epoch 65/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2845 - accuracy: 0.9375
# Epoch 66/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2783 - accuracy: 0.9643
# Epoch 67/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2751 - accuracy: 0.9464
# Epoch 68/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2641 - accuracy: 0.9643
# Epoch 69/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2722 - accuracy: 0.9643
# Epoch 70/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2645 - accuracy: 0.9554
# Epoch 71/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2560 - accuracy: 0.9643
# Epoch 72/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2514 - accuracy: 0.9732
# Epoch 73/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2533 - accuracy: 0.9464
# Epoch 74/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2426 - accuracy: 0.9554
# Epoch 75/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2457 - accuracy: 0.9643
# Epoch 76/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2410 - accuracy: 0.9643
# Epoch 77/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2366 - accuracy: 0.9643
# Epoch 78/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2367 - accuracy: 0.9464
# Epoch 79/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2301 - accuracy: 0.9732
# Epoch 80/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2313 - accuracy: 0.9643
# Epoch 81/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2277 - accuracy: 0.9643
# Epoch 82/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2220 - accuracy: 0.9732
# Epoch 83/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2243 - accuracy: 0.9464
# Epoch 84/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2194 - accuracy: 0.9464
# Epoch 85/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2183 - accuracy: 0.9732
# Epoch 86/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2153 - accuracy: 0.9732
# Epoch 87/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2129 - accuracy: 0.9643
# Epoch 88/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2062 - accuracy: 0.9643
# Epoch 89/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2051 - accuracy: 0.9643
# Epoch 90/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.2043 - accuracy: 0.9643
# Epoch 91/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2023 - accuracy: 0.9643
# Epoch 92/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1965 - accuracy: 0.9732
# Epoch 93/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1949 - accuracy: 0.9732
# Epoch 94/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1992 - accuracy: 0.9643
# Epoch 95/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1932 - accuracy: 0.9643
# Epoch 96/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1929 - accuracy: 0.9643
# Epoch 97/100
# 112/112 [==============================] - 0s 1ms/sample - loss: 0.1880 - accuracy: 0.9554
# Epoch 98/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1883 - accuracy: 0.9643
# Epoch 99/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1904 - accuracy: 0.9643
# Epoch 100/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1884 - accuracy: 0.9554

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Make predictions
# - Predict labels on one row

# %%
model.predict(X_test[0:1])
# Out:
# array([[0.9643599 , 0.03423262, 0.00140749]], dtype=float32)

# %% [markdown]
# ### Compare the prediction with actual label
# - Print the same row as done in the previous step but of actual labels

# %%
y_test[0:1]
# Out:
# array([[1., 0., 0.]], dtype=float32)

# %% [markdown]
# ---

# %% [markdown]
# # Stock prices dataset
# The data is of tock exchange's stock listings for each trading day of 2010 to 2016.
#
# ## Description
# A brief description of columns.
# - open: The opening market price of the equity symbol on the date
# - high: The highest market price of the equity symbol on the date
# - low: The lowest recorded market price of the equity symbol on the date
# - close: The closing recorded price of the equity symbol on the date
# - symbol: Symbol of the listed company
# - volume: Total traded volume of the equity symbol on the date
# - date: Date of record

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Load the data
# - load the csv file and read it using pandas
# - file name is prices.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# run this cell to upload file if you are using google colab
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
stockprice = pd.read_csv('prices.csv')

# %%
stockprice.shape
# Out:
# (851264, 7)

# %%
stockprice.head()
# Out:
#                   date symbol        open  ...         low        high     volume
# 0  2016-01-05 00:00:00   WLTW  123.430000  ...  122.309998  126.250000  2163600.0
# 1  2016-01-06 00:00:00   WLTW  125.239998  ...  119.940002  125.540001  2386400.0
# 2  2016-01-07 00:00:00   WLTW  116.379997  ...  114.930000  119.739998  2489500.0
# 3  2016-01-08 00:00:00   WLTW  115.480003  ...  113.500000  117.440002  2006300.0
# 4  2016-01-11 00:00:00   WLTW  117.010002  ...  114.089996  117.330002  1408600.0
#
# [5 rows x 7 columns]

# %%
stockprice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
# date      851264 non-null object
# symbol    851264 non-null object
# open      851264 non-null float64
# close     851264 non-null float64
# low       851264 non-null float64
# high      851264 non-null float64
# volume    851264 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 45.5+ MB

# %%
stockprice.describe().transpose
# Out:
# <bound method DataFrame.transpose of                 open          close            low           high        volume
# count  851264.000000  851264.000000  851264.000000  851264.000000  8.512640e+05
# mean       70.836986      70.857109      70.118414      71.543476  5.415113e+06
# std        83.695876      83.689686      82.877294      84.465504  1.249468e+07
# min         0.850000       0.860000       0.830000       0.880000  0.000000e+00
# 25%        33.840000      33.849998      33.480000      34.189999  1.221500e+06
# 50%        52.770000      52.799999      52.230000      53.310001  2.476250e+06
# 75%        79.879997      79.889999      79.110001      80.610001  5.222500e+06
# max      1584.439941    1578.130005    1549.939941    1600.930054  8.596434e+08>

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Drop columnns
# - drop "date" and "symbol" column from the data

# %%
stockprice01 = stockprice.drop(['date', 'symbol'], axis=1)

# %%
stockprice01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 5 columns):
# open      851264 non-null float64
# close     851264 non-null float64
# low       851264 non-null float64
# high      851264 non-null float64
# volume    851264 non-null float64
# dtypes: float64(5)
# memory usage: 32.5 MB

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Take initial rows
# - Take first 1000 rows from the data
# - This step is done to make the execution faster

# %%
stockprice02 = stockprice01.head(1000)

# %%
stockprice01.shape
# Out:
# (851264, 5)

# %%
stockprice02.shape
# Out:
# (1000, 5)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - Take "open", "close", "low", "high" columns as features
# - Take "volume" column as label
# - Normalize label column by dividing it with 1000000

# %%
# Seperation of features and target column as given above
X = stockprice02.drop("volume" , axis=1)

y = stockprice02['volume']

# %%
X.shape
# Out:
# (1000, 4)

# %%
y.shape
# Out:
# (1000,)

# %%
#Normalize label column by dividing it with 1000000
y.describe()
# Out:
# count    1.000000e+03
# mean     5.314222e+06
# std      1.446565e+07
# min      1.000000e+04
# 25%      8.216250e+05
# 50%      2.064450e+06
# 75%      4.620475e+06
# max      2.156202e+08
# Name: volume, dtype: float64

# %%
y1 = y/1000000

# %%
y1.describe()
# Out:
# count    1000.000000
# mean        5.314222
# std        14.465650
# min         0.010000
# 25%         0.821625
# 50%         2.064450
# 75%         4.620475
# max       215.620200
# Name: volume, dtype: float64

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Convert data
# - Convert features and labels to numpy array
# - Convert their data type to "float32"

# %%
y2 = y1.to_numpy()

# %%
y2.dtype
# Out:
# dtype('float64')

# %%
X1 = X.to_numpy()

# %%
X1.dtype
# Out:
# dtype('float64')

# %%
X1 = np.float32(X1)

# %%
X1.dtype
# Out:
# dtype('float32')

# %%
y_actual=np.float32(y2)

# %%
y_actual.dtype
# Out:
# dtype('float32')

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Normalize data
# - Normalize features
# - Use tf.math.l2_normalize to normalize features
# - You can read more about it here https://www.tensorflow.org/api_docs/python/tf/math/l2_normalize

# %%
features = tf.math.l2_normalize(X1, axis=None, epsilon=1e-12, name=None)

# %%
x = features

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Define weight and bias
# - Initialize weight and bias with tf.zeros
# - tf.zeros is an initializer that generates tensors initialized to 0
# - Specify the value for shape

# %%
W = tf.zeros(shape=(4, 1)) 
B = tf.zeros(shape=(1))

# %%
W
# Out:
# <tf.Tensor: shape=(4, 1), dtype=float32, numpy=
# array([[0.],
#        [0.],
#        [0.],
#        [0.]], dtype=float32)>

# %%
B
# Out:
# <tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Get prediction
# - Define a function to get prediction
# - Approach: prediction = (X * W) + b; here is X is features

# %%
@tf.function 
def prediction(features, W, B):
  y_pred = tf.add(tf.matmul(features, W), B)
  return y_pred

# %% [markdown]
# ### Calculate loss
# - Calculate loss using predictions
# - Define a function to calculate loss
# - We are calculating mean squared error

# %%
@tf.function 
def loss(y_actual, y_predicted):
  diff = y_actual - y_predicted
  sqr = tf.square(diff)
  avg = tf.reduce_mean(sqr)
  return avg

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Define a function to train the model
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
def train(x, y_actual, w, b, learning_rate=0.01):
  # Record mathematical operations on 'tape' to calculate loss
  with tf.GradientTape() as t:
    t.watch([w,b])
    current_prediction = prediction(x, w, b)
    current_loss = loss(y_actual, current_prediction)
    # Calculate Gradients for Loss with respect to Weights and Bias
    dw, db = t.gradient(current_loss,[w, b])
    # Update Weights and Bias
    w = w - learning_rate * dw
    b = b - learning_rate * db
    return w, b

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Train the model for 100 epochs
# - Observe the training loss at every iteration

# %%
for i in range(100):
  W, B = train(x, y_actual, W, B)
  print('Current Trng Loss on iteration', i, loss(y_actual, prediction(x, W, B)).numpy())
# Out:
# Current Trng Loss on iteration 0 209.52167
# Current Trng Loss on iteration 1 209.50282
# Current Trng Loss on iteration 2 209.48471
# Current Trng Loss on iteration 3 209.46727
# Current Trng Loss on iteration 4 209.45056
# Current Trng Loss on iteration 5 209.43463
# Current Trng Loss on iteration 6 209.41922
# Current Trng Loss on iteration 7 209.40437
# Current Trng Loss on iteration 8 209.3901
# Current Trng Loss on iteration 9 209.37653
# Current Trng Loss on iteration 10 209.36336
# Current Trng Loss on iteration 11 209.35077
# Current Trng Loss on iteration 12 209.33875
# Current Trng Loss on iteration 13 209.3272
# Current Trng Loss on iteration 14 209.31598
# Current Trng Loss on iteration 15 209.30533
# Current Trng Loss on iteration 16 209.29498
# Current Trng Loss on iteration 17 209.28505
# Current Trng Loss on iteration 18 209.27565
# Current Trng Loss on iteration 19 209.26653
# Current Trng Loss on iteration 20 209.25783
# Current Trng Loss on iteration 21 209.24942
# Current Trng Loss on iteration 22 209.24129
# Current Trng Loss on iteration 23 209.23355
# Current Trng Loss on iteration 24 209.22618
# Current Trng Loss on iteration 25 209.219
# Current Trng Loss on iteration 26 209.21211
# Current Trng Loss on iteration 27 209.20543
# Current Trng Loss on iteration 28 209.1992
# Current Trng Loss on iteration 29 209.19315
# Current Trng Loss on iteration 30 209.18727
# Current Trng Loss on iteration 31 209.18167
# Current Trng Loss on iteration 32 209.17625
# Current Trng Loss on iteration 33 209.1711
# Current Trng Loss on iteration 34 209.16614
# Current Trng Loss on iteration 35 209.16135
# Current Trng Loss on iteration 36 209.15677
# Current Trng Loss on iteration 37 209.15233
# Current Trng Loss on iteration 38 209.14813
# Current Trng Loss on iteration 39 209.14404
# Current Trng Loss on iteration 40 209.14023
# Current Trng Loss on iteration 41 209.13647
# Current Trng Loss on iteration 42 209.1328
# Current Trng Loss on iteration 43 209.12941
# Current Trng Loss on iteration 44 209.12616
# Current Trng Loss on iteration 45 209.12294
# Current Trng Loss on iteration 46 209.11995
# Current Trng Loss on iteration 47 209.11693
# Current Trng Loss on iteration 48 209.11407
# Current Trng Loss on iteration 49 209.11142
# Current Trng Loss on iteration 50 209.10883
# Current Trng Loss on iteration 51 209.10634
# Current Trng Loss on iteration 52 209.10394
# Current Trng Loss on iteration 53 209.1016
# Current Trng Loss on iteration 54 209.09937
# Current Trng Loss on iteration 55 209.0973
# Current Trng Loss on iteration 56 209.09526
# Current Trng Loss on iteration 57 209.09325
# Current Trng Loss on iteration 58 209.09142
# Current Trng Loss on iteration 59 209.0896
# Current Trng Loss on iteration 60 209.08786
# Current Trng Loss on iteration 61 209.0861
# Current Trng Loss on iteration 62 209.08455
# Current Trng Loss on iteration 63 209.08301
# Current Trng Loss on iteration 64 209.0816
# Current Trng Loss on iteration 65 209.08011
# Current Trng Loss on iteration 66 209.07875
# Current Trng Loss on iteration 67 209.07738
# Current Trng Loss on iteration 68 209.07623
# Current Trng Loss on iteration 69 209.07506
# Current Trng Loss on iteration 70 209.07388
# Current Trng Loss on iteration 71 209.0727
# Current Trng Loss on iteration 72 209.07169
# Current Trng Loss on iteration 73 209.07062
# Current Trng Loss on iteration 74 209.06963
# Current Trng Loss on iteration 75 209.0687
# Current Trng Loss on iteration 76 209.06778
# Current Trng Loss on iteration 77 209.06685
# Current Trng Loss on iteration 78 209.06609
# Current Trng Loss on iteration 79 209.06525
# Current Trng Loss on iteration 80 209.06448
# Current Trng Loss on iteration 81 209.06375
# Current Trng Loss on iteration 82 209.06305
# Current Trng Loss on iteration 83 209.06236
# Current Trng Loss on iteration 84 209.06166
# Current Trng Loss on iteration 85 209.06111
# Current Trng Loss on iteration 86 209.06046
# Current Trng Loss on iteration 87 209.05986
# Current Trng Loss on iteration 88 209.0593
# Current Trng Loss on iteration 89 209.05882
# Current Trng Loss on iteration 90 209.05824
# Current Trng Loss on iteration 91 209.05779
# Current Trng Loss on iteration 92 209.0573
# Current Trng Loss on iteration 93 209.05676
# Current Trng Loss on iteration 94 209.05644
# Current Trng Loss on iteration 95 209.056
# Current Trng Loss on iteration 96 209.05559
# Current Trng Loss on iteration 97 209.05513
# Current Trng Loss on iteration 98 209.0548
# Current Trng Loss on iteration 99 209.0544

# %% [markdown]
# ### Observe values of Weight
# - Print the updated values

# %%
W
# Out:
# <tf.Tensor: shape=(4, 1), dtype=float32, numpy=
# array([[0.06199218],
#        [0.06210443],
#        [0.06136353],
#        [0.06261288]], dtype=float32)>

# %% [markdown]
# ### Observe values of Bias
# - Print the updated values

# %%
B
# Out:
# <tf.Tensor: shape=(1,), dtype=float32, numpy=array([5.2180204], dtype=float32)>

# %%
B.numpy()
# Out:
# array([5.2180204], dtype=float32)

# %%
W.numpy()
# Out:
# array([[0.06199218],
#        [0.06210443],
#        [0.06136353],
#        [0.06261288]], dtype=float32)
