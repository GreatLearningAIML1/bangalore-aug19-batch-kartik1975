# %%
import numpy as np
import pandas as pd

# %%
fb_df=pd.read_csv("Laliga.csv", header=1)

# %%
fb_df.head(10)
# Out:
#    Pos             Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0    1      Real Madrid       86   4385        2762     1647        552
# 1    2        Barcelona       86   4262        2762     1581        573
# 2    3  Atletico Madrid       80   3442        2614     1241        598
# 3    4         Valencia       82   3386        2664     1187        616
# 4    5  Athletic Bilbao       86   3368        2762     1209        633
# 5    6          Sevilla       73   2819        2408      990        531
# 6    7         Espanyol       82   2792        2626      948        608
# 7    8    Real Sociedad       70   2573        2302      864        577
# 8    9         Zaragoza       58   2109        1986      698        522
# 9   10       Real Betis       51   1884        1728      606        440
#
#   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 0       563     5947         3140       33        23     8      8     3     4
# ...

# %%
## understanding the Data Set 
fb_df.info()
fb_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 20 columns):
# Pos              61 non-null int64
# Team             61 non-null object
# Seasons          61 non-null int64
# Points           61 non-null object
# GamesPlayed      61 non-null object
# GamesWon         61 non-null object
# GamesDrawn       61 non-null object
# GamesLost        61 non-null object
# GoalsFor         61 non-null object
# GoalsAgainst     61 non-null object
# Champion         61 non-null object
# Runner-up        61 non-null object
# Third            61 non-null object
# Fourth           61 non-null object
# Fifth            61 non-null object
# Sixth            61 non-null object
# T                61 non-null object
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null int64
# dtypes: int64(3), object(17)
# memory usage: 9.6+ KB
#              Pos    Seasons  BestPosition
# ...

# %%
##Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data.

# %%
fb_df.replace ('-',0)
# Out:
#     Pos                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1          Real Madrid       86   4385        2762     1647        552
# 1     2            Barcelona       86   4262        2762     1581        573
# 2     3      Atletico Madrid       80   3442        2614     1241        598
# 3     4             Valencia       82   3386        2664     1187        616
# 4     5      Athletic Bilbao       86   3368        2762     1209        633
# 5     6              Sevilla       73   2819        2408      990        531
# 6     7             Espanyol       82   2792        2626      948        608
# 7     8        Real Sociedad       70   2573        2302      864        577
# 8     9             Zaragoza       58   2109        1986      698        522
# 9    10           Real Betis       51   1884        1728      606        440
# 10   11  Deportivo La Coruna       45   1814        1530      563        392
# ...

# %%
fb_df = fb_df.applymap(lambda x: np.nan if x=="-" else x)

# %%
fb_df.columns
# Out:
# Index(['Pos', 'Team', 'Seasons', 'Points', 'GamesPlayed', 'GamesWon',
#        'GamesDrawn', 'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion',
#        'Runner-up', 'Third', 'Fourth', 'Fifth', 'Sixth', 'T', 'Debut',
#        'Since/LastApp', 'BestPosition'],
#       dtype='object')

# %%
for col in ['Seasons', 'Points', 'GamesPlayed', 'GamesWon',
       'GamesDrawn', 'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion',
       'Runner-up', 'Third', 'Fourth', 'Fifth', 'Sixth', 'T']:
    fb_df[col] = pd.to_numeric(fb_df[col])
fb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 21 columns):
# Pos              61 non-null int64
# Team             61 non-null object
# Seasons          61 non-null int64
# Points           60 non-null float64
# GamesPlayed      60 non-null float64
# GamesWon         60 non-null float64
# GamesDrawn       60 non-null float64
# GamesLost        60 non-null float64
# GoalsFor         60 non-null float64
# GoalsAgainst     60 non-null float64
# Champion         9 non-null float64
# Runner-up        13 non-null float64
# Third            18 non-null float64
# Fourth           22 non-null float64
# Fifth            25 non-null float64
# Sixth            28 non-null float64
# T                33 non-null float64
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null int64
# DebutYear        61 non-null int64
# dtypes: float64(14), int64(4), object(3)
# memory usage: 10.1+ KB

# %%
fb_df['Champion'] = pd.to_numeric(fb_df['Champion'])
fb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 20 columns):
# Pos              61 non-null int64
# Team             61 non-null object
# Seasons          61 non-null int64
# Points           60 non-null object
# GamesPlayed      60 non-null object
# GamesWon         60 non-null object
# GamesDrawn       60 non-null object
# GamesLost        60 non-null object
# GoalsFor         60 non-null object
# GoalsAgainst     60 non-null object
# Champion         9 non-null float64
# Runner-up        13 non-null object
# Third            18 non-null object
# Fourth           22 non-null object
# Fifth            25 non-null object
# Sixth            28 non-null object
# T                33 non-null object
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null int64
# dtypes: float64(1), int64(3), object(16)
# memory usage: 9.6+ KB

# %%
fb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 20 columns):
# Pos              61 non-null int64
# Team             61 non-null object
# Seasons          61 non-null int64
# Points           60 non-null object
# GamesPlayed      60 non-null object
# GamesWon         60 non-null object
# GamesDrawn       60 non-null object
# GamesLost        60 non-null object
# GoalsFor         60 non-null object
# GoalsAgainst     60 non-null object
# Champion         9 non-null float64
# Runner-up        13 non-null object
# Third            18 non-null object
# Fourth           22 non-null object
# Fifth            25 non-null object
# Sixth            28 non-null object
# T                33 non-null object
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null int64
# dtypes: float64(1), int64(3), object(16)
# memory usage: 9.6+ KB

# %%
##Print all the teams which have started playing between 1930-1980.

# %%
fb_df ['DebutYear'] = [ year.split("-")[0] for year in fb_df ['Debut']]
fb_df ['DebutYear'] = pd.to_numeric( fb_df ['DebutYear'])
fb_df .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 21 columns):
# Pos              61 non-null int64
# Team             61 non-null object
# Seasons          61 non-null int64
# Points           60 non-null object
# GamesPlayed      60 non-null object
# GamesWon         60 non-null object
# GamesDrawn       60 non-null object
# GamesLost        60 non-null object
# GoalsFor         60 non-null object
# GoalsAgainst     60 non-null object
# Champion         9 non-null float64
# Runner-up        13 non-null object
# Third            18 non-null object
# Fourth           22 non-null object
# Fifth            25 non-null object
# Sixth            28 non-null object
# T                33 non-null object
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null int64
# DebutYear        61 non-null int64
# dtypes: float64(1), int64(4), object(16)
# memory usage: 10.1+ KB

# %%
fb_df [fb_df ['DebutYear'].between(1930, 1980)]['Team']
# Out:
# 3                Valencia
# 5                 Sevilla
# 8                Zaragoza
# 9              Real Betis
# 10    Deportivo La Coruna
# 11             Celta Vigo
# 12             Valladolid
# 14         Sporting Gijon
# 15                Osasuna
# 16                 Malaga
# 17                 Oviedo
# 18               Mallorca
# 19             Las Palmas
# 21                Granada
# 22         Rayo Vallecano
# 23                  Elche
# 25               Hercules
# 26               Tenerife
# 27                 Murcia
# 28                 Alaves
# 29                Levante
# 30              Salamanca
# 31               Sabadell
# 32                  Cadiz
# 34              Castellon
# 37                Cordoba
# 39             Recreativo
# 40              Burgos CF
# 41             Pontevedra
# 46              Gimnastic
# 49               Alcoyano
# 50                   Jaen
# 52             AD Almeria
# 54                 Lleida
# 57                 Condal
# ...

# %%
##Print the list of teams which came Top 5 in terms of points
## The result below is not correct. Not sure why the data is not being represented. Request help.

# %%
fb_df.sort_values(by='Points',ascending=False).head(5)['Team']
# Out:
# 0        Real Madrid
# 1          Barcelona
# 2    Atletico Madrid
# 3           Valencia
# 4    Athletic Bilbao
# Name: Team, dtype: object

# %%
##Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. 
##Using the same function, find the team which has maximum and minimum goal difference.

# %%
# function to return all the teams with their Goal Differences
def Goal_diff_count(df,fromCol,ToCol,diff):
    df[diff] = df[fromCol] - df[ToCol]
    return df
result = Goal_diff_count(fb_df,'GoalsFor','GoalsAgainst','goal_diff')

# %%
def Goal_diff_count():
    return fb_df['GoalsFor']-fb_df['GoalsAgainst']
fb_df['Goal_diff_count']= Goal_diff_count()
print(fb_df)
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0     1          Real Madrid       86  4385.0       2762.0    1647.0
# 1     2            Barcelona       86  4262.0       2762.0    1581.0
# 2     3      Atletico Madrid       80  3442.0       2614.0    1241.0
# 3     4             Valencia       82  3386.0       2664.0    1187.0
# 4     5      Athletic Bilbao       86  3368.0       2762.0    1209.0
# 5     6              Sevilla       73  2819.0       2408.0     990.0
# 6     7             Espanyol       82  2792.0       2626.0     948.0
# 7     8        Real Sociedad       70  2573.0       2302.0     864.0
# 8     9             Zaragoza       58  2109.0       1986.0     698.0
# 9    10           Real Betis       51  1884.0       1728.0     606.0
# 10   11  Deportivo La Coruna       45  1814.0       1530.0     563.0
# 11   12           Celta Vigo       51  1789.0       1698.0     586.0
# 12   13           Valladolid       42  1471.0       1466.0     463.0
# ...

# %%
print(max(fb_df['goal_diff']))
#print(min(fb_df['goal_diff']))
print("team with max diff of",max(fb_df['goal_diff']),"is",fb_df.sort_values(by='goal_diff',ascending=True).head(1)['Team'].values[0])
print("team with min diff of",min(fb_df['goal_diff']),"is",fb_df.sort_values(by='goal_diff',ascending=False).head(1)['Team'].values[0])
# Out:
# 2807.0
# team with max diff of 2807.0 is Racing Santander
# team with min diff of -525.0 is Real Madrid

# %%
##Create a new column with name “Winning Percent” and append it to the data set
Percentage of Winning = (GamesWon / GamesPlayed)*100

If there are any numerical error, replace it with 0%

Print the top 5 teams which has the highest Winning percentage
# Out:
#   File "<ipython-input-168-8f0ec16f358b>", line 2
#     Percentage of Winning = (GamesWon / GamesPlayed)*100
#                 ^
# SyntaxError: invalid syntax

# %%
fb_df['Percentage of Win'] = fb_df['GamesWon']/fb_df['GamesPlayed']*100

# %%
fb_df['Percentage of Win'].fillna(0,inplace=True)
fb_df['Percentage of Win']
print("The top 5 teams with highest Win percentage are")
for i in range(0,5):
    print(fb_df.sort_values(by='Percentage of Winning',ascending=False).head(5)['Team'][i],"with",round(fb_df.sort_values(by='Percentage of Winning',ascending=False).head(5)['Percentage of Winning'][i],1),"%")
# Out:
# The top 5 teams with highest Win percentage are
# Real Madrid with 59.6 %
# Barcelona with 57.2 %
# Atletico Madrid with 47.5 %
# Valencia with 44.6 %
# Athletic Bilbao with 43.8 %

# %%
print("The sum of all points grouped by 'Best Position' per each 'Best Position' is:")
pd.DataFrame(fb_df.groupby(by='BestPosition').agg(sum)['Points'])
# Out:
# The sum of all points grouped by 'Best Position' per each 'Best Position' is:
#                Points
# BestPosition
# 1             27933.0
# 2              6904.0
# 3              5221.0
# 4              6563.0
# 5              1884.0
# 6              2113.0
# 7              1186.0
# 8              1134.0
# 9                96.0
# 10              450.0
# 11              445.0
# 12              511.0
# 14               71.0
# 15               14.0
# 16               81.0
# 17              266.0
# 19               81.0
# 20               34.0
